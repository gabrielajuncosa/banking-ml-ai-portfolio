# %% [markdown]
# # UGST4012 - Digital Tools for the Social Sciences
# ## Central European University, Winter 2020/2021
# ## LAB 1
# Author: Gabriela Juncosa, PhD

# %% [markdown]
# ### types
# |Type|Name|Example
# |---|---|---
# |int|Integer|30,-4
# |float|Floating point|1.5,1e10
# |str|String|"alma","c"
# |bool|Boolean|True,False
# |list|List|\[1,"alma",2\]
# |dict|Dictionary|\{'course': "SciPy", 'teacher': "JT"\}

# %%
a = 7
b = 3.14

c = True
d = "alma"
e = [1, 2]
d = {'course': "SciPy", 'teacher': "JT", }
type(a),type(b),type(c),type(d),type(e)
# Out:
# (int, float, bool, dict, list)

# %%
list1 = [1,3,5,7,9]

# %%
list1[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-efc5536bcf79> in <module>
# ----> 1 list1[5]
#
# IndexError: list index out of range

# %%
list1[4]
# Out:
# 9

# %%
list1[-1]
# Out:
# 9

# %% [markdown]
# name_function(arguments)

# %%
len(list1)
# Out:
# 5

# %%
type(list1)
# Out:
# list

# %%
type(list1[0])
# Out:
# int

# %%
name = ['Amelia', 'Laura','Fikhar']
age = [18,21,19]
height = [1.80, 1.53, 1.70]

# %%
print(type(name),type(age),type(height))
# Out:
# <class 'list'> <class 'list'> <class 'list'>

# %%
print(type(name[0]),type(age[0]),type(height[0]))
# Out:
# <class 'str'> <class 'int'> <class 'float'>

# %%
class_info = [['Amelia', 'Laura','Fikhar'],[18,21,19] ,[1.80, 1.53, 1.70]]

# %%
type(class_info)
# Out:
# list

# %%
len(class_info)
# Out:
# 3

# %%
type(class_info[0])
# Out:
# list

# %%
class_info[0][0]
# Out:
# 'Amelia'

# %%
type(class_info[0][0])
# Out:
# str

# %%
class_info[1][1]
# Out:
# 21

# %%
print(range(len(class_info)))
# Out:
# range(0, 3)

# %%
for i in range(len(class_info)):
    print(class_info[i][2])
# Out:
# Fikhar
# 19
# 1.7

# %%
for item in class_info: 
    print(item[1])
# Out:
# Laura
# 21
# 1.53

# %% [markdown]
# ### List

# %%
a = [ 7, 3 ,8, 10, 7, 1, 9, 1, 5]
print(a)
print(type(a))
# Out:
# [7, 3, 8, 10, 7, 1, 9, 1, 5]
# <class 'list'>

# %%
print(a[0])
print(a[0:4])
print(a[-1])
# Out:
# 7
# [7, 3, 8, 10]
# 5

# %%
a = [1, "a", [1, 2], {"name", "Torok"}]
print(a[0], a[1], a[2], a[3])
# Out:
# 1 a [1, 2] {'name', 'Torok'}

# %%
a += [ "körte", True ]
print(a)
# Out:
# [1, 'a', [1, 2], {'name', 'Torok'}, 'körte', True]

# %%
b = []
a = [ 1, 2 ]
print(b)
b.append("a")
b.append(5)
b.append(a)
print(b)
b.remove("a")
print("a removed:", b)
print(b)
print("Pop",b.pop())
a.reverse()
print("a reversed:",a)

# %%
print(list(range(10)))
print(list(range(3,10,2)))

# %% [markdown]
# ### Strings

# %%
s = "Hello world!"
print(s)
# Out:
# Hello world!

# %%
print(s[0],s[1],s[-1],s[-2])
print(s[0:4],s[:4])
print(s[0:-1])
print(s[0:-1:2],s[::2])

# %% [markdown]
# #### Useful string methods

# %%
s = "Helló világ!\n"
print(s[6:].capitalize() + "XXX")
print(s.rstrip() + "YYY")
print(s.count("l"))
print(s.index("l"))
print("123".isdigit(),"1e3".isdigit(),s.isprintable(),"Körte".isprintable())
print(s.split("l"))
print(s.strip("\n! lH"))
print(s.upper())
# Out:
# Világ!
# XXX
# Helló világ!YYY
# 3
# 2
# True False False True
# ['He', '', 'ó vi', 'ág!\n']
# elló világ
# HELLÓ VILÁG!

# %% [markdown]
# ### Basic python instructions
#
# Let's start learning how to read the documentation. (and let's do a recap of python's control flow statements.)
# From the <a href="https://docs.python.org/3/reference/compound_stmts.html">reference guide</a>:
#
# #### The while statement
#
# The while statement is used for repeated execution as long as an expression is true:
#
# <code>
# while_stmt ::=  "while" expression ":" suite
#                 ["else" ":" suite]
# </code>
# <code>
# suite         ::=  stmt_list NEWLINE | NEWLINE INDENT statement+ DEDENT<br>
# statement     ::=  stmt_list NEWLINE | compound_stmt<br>
# stmt_list     ::=  simple_stmt (";" simple_stmt)* [";"]
# </code>
#
# This repeatedly tests the expression and, if it is true, executes the first suite; if the expression is false (which may be the first time it is tested) the suite of the else clause, if present, is executed and the loop terminates.
#
# A break statement executed in the first suite terminates the loop without executing the else clause’s suite. A continue statement executed in the first suite skips the rest of the suite and goes back to testing the expression.

# %%
f = 1.0
v = 1.0
while f * v < 1e10:
    f *= v
    v += 1.0
print("The largest factorial less than 1e10 is: %d! = %g" % (v - 1, f))

# %% [markdown]
# #### The if statement
#
# <code>
# if_stmt ::=  "if" expression ":" suite
#                 ("elif" expression ":" suite)*
#                 ["else" ":" suite]
# </code>

# %% [markdown]
# #### The for statement
#
# <code>
# for_stmt ::=  "for" target_list "in" expression_list ":" suite
#                  ["else" ":" suite]
# </code>

# %%
for a in range(10):
    if a < 5:
        print(a)
    else:
        print(10-a)

# %% [markdown]
# ### Dictionaries
#
# Dictionaries are also like lists, except that each element is a key-value pair. The syntax for dictionaries is `{key1 : value1, key2 : value 2, ...}`:

# %%
D = {0 : k for k in ['a', 'b', 'c']}
print(D)

# %%
fruits = {"bananas" : 1,
          "oranges" : 2,
          "apples" : 3,}

print(type(fruits))
print(fruits)

# %%
type(fruits.values())

# %%
print("bananas = " + str(fruits["bananas"]))
print("oranges = " + str(fruits["oranges"]))
print("apples = " + str(fruits["apples"]))

# %%
fruits["bananas"] = "no bananas"
fruits["oranges"] = 100

# add a new entry
fruits["pineapples"] = "D"

print("bananas = " + str(fruits["bananas"]))
print("oranges = " + str(fruits["oranges"]))
print("apples = " + str(fruits["apples"]))
print("pineapples = " + str(fruits["pineapples"]))

# %% [markdown]
# Strings, numbers, and tuples work as keys, and any type can be a value. Other types may or may not work correctly as keys (strings and tuples work cleanly since they are immutable). Looking up a value which is not in the dict throws a KeyError -- use "in" to check if the key is in the dict, or use dict.get(key) which returns the value or None if the key is not present (or get(key, not-found) allows you to specify what value to return in the not-found case).

# %%
print(fruits['bananas'])     ## Simple lookup, returns 'bananas'

# %% [markdown]
# If you try to access something that does not exists in the dictionary, you will get an error:

# %%
print(fruits['strawberries'])

# %% [markdown]
# To avoid key errors, you can simply check with an ``if`` that the key is present in the dictionary:

# %%
if 'bananas' in fruits: print(fruits['bananas']) ## Yes, you can also write an if in this way 

if 'strawberries' in fruits: print (fruits['strawberries']) ## and an if-else in this way 
else: print("I don\'t know what a strawberry is")

# %% [markdown]
# An alternative way to access keys in a dictionary is with the method ``get``. If the key does not exist you get a None:

# %%
print(fruits.get('bananas'))
print(fruits.get('strawberries'))

# %% [markdown]
# To iterate over key-value pairs of a dictionary:

# %%
for key in fruits: 
    print(key, fruits[key])

# %% [markdown]
# This iteration is equivalent to iterating over ```fruits.keys()```:

# %%
for key in fruits.keys(): 
    print(key)

# %%
type(fruits.keys())

# %% [markdown]
# If you want to show the values instead:

# %%
for value in fruits.values():
    print(value)

# %%
type(fruits.values)

# %% [markdown]
# If you want to show both at the same time, you can use fruits.items()

# %%
for key, value in fruits.items():
    print(key + " = " + str(value))

# %% [markdown]
# _**Note that the keys are not sorted, nor are listed in the order you added them to the dictionary!**_ If you want to do that, you should sort the keys first

# %%
for key in sorted(fruits.keys()):
    print(key, fruits[key])

# %%
for value in sorted(fruits.values()):
    print(value)

# %% [markdown]
# ### Dataframes with Pandas
#
# https://pandas.pydata.org/docs/

# %%
import pickle

with open("cnnVidsInfo.txt", "rb") as fp:
    rawDta = pickle.load(fp)
# Out:
# 20000

# %%
print(len(rawDta))
print(type(rawDta))
# Out:
# 20000
# <class 'list'>

# %%
print(rawDta[0])
print(type(rawDta[0]))
# Out:
# {'kind': 'youtube#playlistItem', 'etag': 'bCIpIP-RN2sbOrhzCDnV4ADvdyc', 'id': 'VVV1cHZaRy01a29fZWlYQXVwYkRmeFd3LnQ4Tk8tRGVRR0lB', 'snippet': {'publishedAt': '2021-01-11T14:16:13Z', 'channelId': 'UCupvZG-5ko_eiXAupbDfxWw', 'title': "'Untethered from reality': Alisyn Camerota calls out Trump supporters", 'description': "CNN's Alisyn Camerota shares her thoughts on the President's supporters after pro-Trump rioters stormed the US Capitol. #CNN #News", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/t8NO-DeQGIA/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/t8NO-DeQGIA/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/t8NO-DeQGIA/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/t8NO-DeQGIA/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/t8NO-DeQGIA/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'CNN', 'pl
# ...

# %%
rawDta[0].keys()
# Out:
# dict_keys(['kind', 'etag', 'id', 'snippet'])

# %%
rawDta[0]['snippet'].keys()
# Out:
# dict_keys(['publishedAt', 'channelId', 'title', 'description', 'thumbnails', 'channelTitle', 'playlistId', 'position', 'resourceId'])

# %%
rawDta[0]['snippet']['resourceId'].keys()
# Out:
# dict_keys(['kind', 'videoId'])

# %%
dataframe = []
for i in range(len(rawDta)):
    aux = (rawDta[i]['snippet']['channelTitle'],
           rawDta[i]['snippet']['channelId'], 
           rawDta[i]['snippet']['publishedAt'],
           rawDta[i]['snippet']['resourceId']['videoId'], 
           rawDta[i]['snippet']['title'], 
           rawDta[i]['snippet']['description'])
    
    dataframe.append(aux)

# %%
dataframe[0]
# Out:
# ('CNN',
#  'UCupvZG-5ko_eiXAupbDfxWw',
#  '2021-01-11T14:16:13Z',
#  't8NO-DeQGIA',
#  "'Untethered from reality': Alisyn Camerota calls out Trump supporters",
#  "CNN's Alisyn Camerota shares her thoughts on the President's supporters after pro-Trump rioters stormed the US Capitol. #CNN #News")

# %%
import pandas as pd 

videoInfo = pd.DataFrame(dataframe, 
                            columns = ['channelTitle', 'channelId', 'publishedAt',
                                       'videoId', 'title', 'description'])
videoInfo.head()
# Out:
#   channelTitle                 channelId           publishedAt      videoId  \
# 0          CNN  UCupvZG-5ko_eiXAupbDfxWw  2021-01-11T14:16:13Z  t8NO-DeQGIA
# 1          CNN  UCupvZG-5ko_eiXAupbDfxWw  2021-01-11T13:25:33Z  BgEU7qIYzhI
# 2          CNN  UCupvZG-5ko_eiXAupbDfxWw  2021-01-10T18:49:59Z  jEtpKUUxVGQ
# 3          CNN  UCupvZG-5ko_eiXAupbDfxWw  2021-01-10T18:10:10Z  gmpkorhW8hQ
# 4          CNN  UCupvZG-5ko_eiXAupbDfxWw  2021-01-09T19:35:42Z  uRsf-MYO8DA
#
#                                                title  \
# 0  'Untethered from reality': Alisyn Camerota cal...
# 1  Why Colin Powell says he no longer considers h...
# 2  King: We thought these Covid-19 numbers were b...
# 3  Tapper: Will there be any consequences for the...
# 4    More arrests made after riots at the US Capitol
#
#                                          description
# 0  CNN's Alisyn Camerota shares her thoughts on t...
# 1  Former Secretary of State Colin Powell weighs ...
# ...

# %%
videoInfo['month'] = [int(videoInfo['publishedAt'][i][5:7]) for i in range(len(videoInfo['publishedAt']))]
videoInfo['year'] = [int(videoInfo['publishedAt'][i][:4]) for i in range(len(videoInfo['publishedAt']))]
videoInfo['day'] = [int(videoInfo['publishedAt'][i][8:10]) for i in range(len(videoInfo['publishedAt']))]

videoInfo.head()
# Out:
#   channelTitle                 channelId           publishedAt      videoId  \
# 0          CNN  UCupvZG-5ko_eiXAupbDfxWw  2021-01-11T14:16:13Z  t8NO-DeQGIA
# 1          CNN  UCupvZG-5ko_eiXAupbDfxWw  2021-01-11T13:25:33Z  BgEU7qIYzhI
# 2          CNN  UCupvZG-5ko_eiXAupbDfxWw  2021-01-10T18:49:59Z  jEtpKUUxVGQ
# 3          CNN  UCupvZG-5ko_eiXAupbDfxWw  2021-01-10T18:10:10Z  gmpkorhW8hQ
# 4          CNN  UCupvZG-5ko_eiXAupbDfxWw  2021-01-09T19:35:42Z  uRsf-MYO8DA
#
#                                                title  \
# 0  'Untethered from reality': Alisyn Camerota cal...
# 1  Why Colin Powell says he no longer considers h...
# 2  King: We thought these Covid-19 numbers were b...
# 3  Tapper: Will there be any consequences for the...
# 4    More arrests made after riots at the US Capitol
#
#                                          description  month  year  day
# 0  CNN's Alisyn Camerota shares her thoughts on t...      1  2021   11
# ...

# %%
videoInfo_fil = videoInfo[videoInfo['year'] == 2020] 
print(videoInfo_fil)
# Out:
#      channelTitle                 channelId           publishedAt  \
# 85            CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-12-31T23:24:43Z
# 86            CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-12-31T18:44:47Z
# 87            CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-12-31T16:47:50Z
# 88            CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-12-31T16:35:42Z
# 89            CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-12-31T04:50:14Z
# ...           ...                       ...                   ...
# 3055          CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-01-01T12:08:58Z
# 3056          CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-01-01T08:59:58Z
# 3057          CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-01-01T06:35:43Z
# 3058          CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-01-01T06:14:33Z
# 3059          CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-01-01T06:06:07Z
#
#           videoId                                              title  \
# 85    O3sLnIVQqlw  140 House Republicans expected to oppose Biden...
# ...

# %%
videoInfo_fil = videoInfo_fil[videoInfo_fil['month'] > 8] 
print(videoInfo_fil)
# Out:
#     channelTitle                 channelId           publishedAt      videoId  \
# 85           CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-12-31T23:24:43Z  O3sLnIVQqlw
# 86           CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-12-31T18:44:47Z  Ce14WTJ0XWU
# 87           CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-12-31T16:47:50Z  yK2bmGnKLYw
# 88           CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-12-31T16:35:42Z  EMYlhSexV9E
# 89           CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-12-31T04:50:14Z  BWPoDkUitBo
# ..           ...                       ...                   ...          ...
# 868          CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-09-01T14:05:08Z  DdOGbxZeQGU
# 869          CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-09-01T13:22:55Z  Hp2KI7A8440
# 870          CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-09-01T04:54:16Z  a5COvnGH_Zg
# 871          CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-09-01T04:15:54Z  UH2dqHFOOlo
# 872          CNN  UCupvZG-5ko_eiXAupbDfxWw  2020-09-01T00:11:02Z  9ixTaQpfGog
#
# ...
