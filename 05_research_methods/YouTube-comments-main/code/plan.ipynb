# %% [markdown]
# ### Channels
# - ABC
# - Fox
# - CNN
# - CBS
#
# ### Topics
# - Politics
# - Sports
# - Weather
#
#
# ### Videos
# - jkjk
# - kjkjkjk
# - jjkjkjkj
#
# ### Authors
#
# - ttuzuz
# - uhfhaghh
# - iooijjhj
#
#
# Characterize the users
#
# - community detection for users based on the projection matrix from videos
# - use attributes of their comments to check
# - calculate jaccard index for different users.
# - see if similar types of people comment on specific videos of a particular channel

# %% [markdown]
# https://github.com/gabrielajuncosa/YouTube-comments.git
